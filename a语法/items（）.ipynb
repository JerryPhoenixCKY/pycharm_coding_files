# %% [markdown]
# ## ✅ 基本语法
#
# ```python
# dict.items()
# ```
#
# - 返回一个 **`dict_items` 对象**（可迭代，但不是列表）
# - 每个元素是一个 **元组 `(key, value)`**
#
# ---
#
# ## 🧪 示例说明
#
# ```python
# student = {
#     "name": "Alice",
#     "age": 20,
#     "grade": "A"
# }
#
# # 获取所有键值对
# pairs = student.items()
# print(pairs)
# # 输出: dict_items([('name', 'Alice'), ('age', 20), ('grade', 'A')])
#
# # 转成列表（可选）
# print(list(pairs))
# # [('name', 'Alice'), ('age', 20), ('grade', 'A')]
# ```
#
# ---
#
# ## 🔁 常见用法：遍历字典
#
# 这是 `items()` **最常用的地方**！
#
# ### ✅ 正确方式（推荐）：
# ```python
# for key, value in student.items():
#     print(f"{key}: {value}")
# ```
#
# 输出：
# ```
# name: Alice
# age: 20
# grade: A
# ```
#
#
#
# > ✅ 用 `items()` 更清晰、更高效，尤其当需要同时用到 key 和 value 时。
#
# ---
#
# ## 🛠 实际应用场景
#
# ### 1. 打印或处理所有键值对
# ```python
# config = {"host": "localhost", "port": 8080, "debug": True}
# for k, v in config.items():
#     print(f"Setting {k} = {v}")
# ```
#
# ### 2. 构造新字典（字典推导式）
# ```python
# # 把所有值转为字符串
# str_config = {k: str(v) for k, v in config.items()}
# # {'host': 'localhost', 'port': '8080', 'debug': 'True'}
# ```
#
# ### 3. 在 anagram 分组中调试
# ```python
# groups = {'eilnst': ['listen', 'silent'], 'art': ['rat', 'tar']}
# for key, words in groups.items():
#     print(f"Anagram group {key}: {words}")
# ```
#
#
# > 💡 它们都是**动态视图**（view），如果原字典变了，视图也会变（但通常我们直接遍历，不存储）。
#
# ---
#
# ## ⚠️ 注意事项
#
# - `items()` 返回的不是列表，不能直接索引：
#   ```python
#   pairs = d.items()
#   print(pairs[0])  # ❌ TypeError!
#   ```
#   ✅ 如果需要索引，先转列表：
#   ```python
#   print(list(pairs)[0])  # ('a', 1)
#   ```
#
# - 在循环中修改字典大小会报错（运行时不能改变字典结构）：
#   ```python
#   for k, v in d.items():
#       del d[k]  # ❌ RuntimeError: dictionary changed size during iteration
#   ```
#
# ---
#
# ## ✅ 总结
#
# | 用途 | 代码 |
# |------|------|
# | 遍历字典的键和值 | `for k, v in d.items():` |
# | 调试查看内容 | `print(list(d.items()))` |
# | 构造新数据结构 | `{k.upper(): v for k, v in d.items()}` |
